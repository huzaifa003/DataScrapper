# %%
# %pip install textblob
# %pip install bs4
# %pip install lxml
# %pip install openpyxl
# %pip install nltk
# Out:
# ...
#
# [notice] A new release of pip is available: 23.2.1 -> 23.3
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# ...
#
# [notice] A new release of pip is available: 23.2.1 -> 23.3
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# ...
#
# [notice] A new release of pip is available: 23.2.1 -> 23.3
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# ...
#
# [notice] A new release of pip is available: 23.2.1 -> 23.3
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# ...
#
# [notice] A new release of pip is available: 23.2.1 -> 23.3
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import nltk
nltk.download('brown')
nltk.download('averaged_perceptron_tagger')
import pandas as pd
import requests
from bs4 import BeautifulSoup
from textblob import TextBlob
# Out:
# [nltk_data] Downloading package brown to /home/codespace/nltk_data...
# [nltk_data]   Package brown is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /home/codespace/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!

# %%
data = requests.get("https://mistore.pk/collections/redmi-phones")
soup = BeautifulSoup(data.content, 'lxml')

mobiles = soup.find("div", {"class" : "product-collection products-grid"})
mobiles
# Out:
# <div class="product-collection products-grid">
# <div class="no_crop_image grid-item col-xs-3 col-md-3">
# <div class="inner product-item on-sale wow fadeIn" data-id="6881745338448" data-wow-delay="0ms" id="product-6881745338448">
# <div class="inner-top">
# <div class="product-top">
# <div class="product-image">
# <a class="product-grid-image" href="/products/redmi-12-mi-lcd-writing-tablet">
# <img alt="Redmi 12 + Mi LCD Writing Tablet 13.5" src="//mistore.pk/cdn/shop/files/Artboard4copy_300x.jpg?v=1697104763"/>
# <!--           <div class="hover"></div> -->
# </a>
# </div>
# <!--  { % if product.variants.first.inventory_management == "shopify" and product.variants.first.inventory_quantity > 0 %} -->
# <div class="product-label">
# <strong class="label">
# <!--          { { price_diff | times: 100 | divided_by: product.compare_at_price_max }}% OFF -->
#           Save Rs. 699
#         </strong>
# <!-- -->
# </div>
# <!--    { % endif  %} -->
# ...

# %%
mobile_divs = mobiles.find_all("div", {"class": "no_crop_image  grid-item col-xs-3 col-md-3"})
print(len(mobile_divs))
mobile_divs
# Out:
# 0
# []
